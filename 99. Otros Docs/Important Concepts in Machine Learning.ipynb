# %% [markdown]
# # Important Concepts in Machine Learning (A12-A14)

# %% [markdown]
# - ### Supervised Learning vs Unsupervised Learning
#
#     <details>
#       <summary>Click me</summary>
#         Supervised learning is to learn a mapping from input features to output labels based on the labeled training data.
#     </details>

# %% [markdown]
# - ### The template for Scikit-Learn
# <details>
#   <summary>Click me</summary>
#    ### The Template
#
#   ```python
#         from sklearn.module import Model
#         model = Model()
#         model.fit(X, y)
#         predictions = model.predict(X_new)
#         print(predictions)
#   ```
# </details>

# %% [markdown]
# - ### Classification vs Regression

# %% [markdown]
# - ### Overfitting (Low Bias but High Variance) vs Underfitting (High Bias but Low Variance)
# <details>
#   <summary>Click me</summary>
#      https://docs.aws.amazon.com/machine-learning/latest/dg/model-fit-underfitting-vs-overfitting.html
#
#      https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff
# </details>
#
#
# [Amazon Example] (https://docs.aws.amazon.com/machine-learning/latest/dg/model-fit-underfitting-vs-overfitting.html)
#
#
# ![image.png](attachment:image.png)
#
#
#
# [variance trade off] (https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff)

# %% [markdown]
# - ### Confusion Matrix and Different performance metrics (Accuracy, Precision, Recall, F1 Score)
#
#     <details>
#     <summary>Click me</summary>
#
#     |   | Predicted Legit | Predicted Fradulent |
#     |-------|-----|--------|
#     | **Actual Legit** | true negative  | false positive |
#     | **Actual Fraudulent**   | false negative  | true negative   |
#
#     </details>

# %% [markdown]
# - ### Cross Validation
#
#     <details>
#       <summary>Click me</summary>
#
#          https://miro.medium.com/v2/resize:fit:1400/1*lFoU-sFudj08qZbVVQkbyg.png
#
#          https://miro.medium.com/v2/resize:fit:720/format:webp/1*AAwIlHM8TpAVe4l2FihNUQ.png
#
#     </details>
#
# [k-folds Cross Validation](https://miro.medium.com/v2/resize:fit:1400/1*lFoU-sFudj08qZbVVQkbyg.png)
# ![image.png](attachment:image.png)
#
#
#
# [Cross Validation](https://miro.medium.com/v2/resize:fit:720/format:webp/1*AAwIlHM8TpAVe4l2FihNUQ.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - ### Regularization

# %% [markdown]
# - ### One-Hot Encoding
#
#   <details>
#       <summary>Click me</summary>
#         https://miro.medium.com/v2/resize:fit:1200/1*ggtP4a5YaRx6l09KQaYOnw.png
#     </details>
# ![image.png](attachment:image.png)

# %% [markdown]
# - ### Stratified Sampling
#
#     <details>
#       <summary>Click me</summary>
#             https://faculty.elgin.edu/dkernler/statistics/ch01/images/strata-sample.gif
#     </details>
#
#     ![image.png](attachment:image.png)

# %% [markdown]
# - ### Hyperparameter Tuning
#     - Grid Search
#     - Random Search

# %% [markdown]
# - ### Feature Engineering and the Curse of High Dimensionality
#     <details>
#       <summary>Click me</summary>
#     In an abstract sense, as the number of features or dimensions grows, the amount of data we need to generalize accurately grows exponentially.    </details>
