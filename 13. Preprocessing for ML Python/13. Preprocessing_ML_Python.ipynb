# %% [markdown]
# # **13. Preprocessing for Machine Learning in Python**
# [Link](https://github.com/goodboychan/goodboychan.github.io/blob/main/_notebooks/2020-07-09-02-Introduction-to-Data-Preprocessing.ipynb)

# %% [markdown]
# ## Chapter 1 - Introduction to Data Preprocessing
# > In this chapter you'll learn exactly what it means to preprocess data. You'll take the first steps in any preprocessing journey, including exploring data types and dealing with missing data. This is the Summary of lecture "Preprocessing for Machine Learning in Python", via datacamp.
#
# - toc: true
# - badges: true
# - comments: true
# - author: Chanseok Kang
# - categories: [Python, Datacamp, Machine_Learning]
# - image:

# %%
import pandas as pd

# %% [markdown]
# ### What is data preprocessing?
# - Data Preprocessing
#     - Beyond cleaning and exploratory data analysis
#     - Prepping data for modeling
#     - Modeling in python requires numerical input

# %% [markdown]
# ### Missing data - columns
# We have a dataset comprised of volunteer information from New York City. The dataset has a number of features, but we want to get rid of features that have at least 3 missing values.

# %%
volunteer = pd.read_csv('volunteer_opportunities.csv')
volunteer.head()
# Out:
#    opportunity_id  content_id  vol_requests  event_time  \
# 0            4996       37004            50           0
# 1            5008       37036             2           0
# 2            5016       37143            20           0
# 3            5022       37237           500           0
# 4            5055       37425            15           0
#
#                                                title  hits  \
# 0  Volunteers Needed For Rise Up & Stay Put! Home...   737
# 1                                       Web designer    22
# 2      Urban Adventures - Ice Skating at Lasker Rink    62
# 3  Fight global hunger and support women farmers ...    14
# 4                                      Stop 'N' Swap    31
#
#                                              summary is_priority  category_id  \
# 0  Building on successful events last summer and ...         NaN          NaN
# 1             Build a website for an Afghan business         NaN          1.0
# 2  Please join us and the students from Mott Hall...         NaN          1.0
# 3  The Oxfam Action Corps is a group of dedicated...         NaN          1.0
# 4  Stop 'N' Swap reduces NYC's waste by finding n...         NaN          4.0
#
#                category_desc  ...     end_date_date    status Latitude  \
# 0                        NaN  ...      July 30 2011  approved      NaN
# 1  Strengthening Communities  ...  February 01 2011  approved      NaN
# 2  Strengthening Communities  ...   January 29 2011  approved      NaN
# 3  Strengthening Communities  ...     March 31 2012  approved      NaN
# 4                Environment  ...  February 05 2011  approved      NaN
#
#    Longitude  Community Board Community Council  Census Tract  BIN  BBL NTA
# 0        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 1        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 2        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 3        NaN              NaN                NaN          NaN  NaN  NaN NaN
# 4        NaN              NaN                NaN          NaN  NaN  NaN NaN
#
# [5 rows x 35 columns]

# %%
volunteer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 665 entries, 0 to 664
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   opportunity_id      665 non-null    int64
#  1   content_id          665 non-null    int64
#  2   vol_requests        665 non-null    int64
#  3   event_time          665 non-null    int64
#  4   title               665 non-null    object
#  5   hits                665 non-null    int64
#  6   summary             665 non-null    object
#  7   is_priority         62 non-null     object
#  8   category_id         617 non-null    float64
#  9   category_desc       617 non-null    object
#  10  amsl                0 non-null      float64
#  11  amsl_unit           0 non-null      float64
#  12  org_title           665 non-null    object
#  13  org_content_id      665 non-null    int64
#  14  addresses_count     665 non-null    int64
#  15  locality            595 non-null    object
#  16  region              665 non-null    object
#  17  postalcode          659 non-null    float64
#  18  primary_loc         0 non-null      float64
#  19  display_url         665 non-null    object
#  20  recurrence_type     665 non-null    object
#  21  hours               665 non-null    int64
#  22  created_date        665 non-null    object
#  23  last_modified_date  665 non-null    object
#  24  start_date_date     665 non-null    object
#  25  end_date_date       665 non-null    object
#  26  status              665 non-null    object
#  27  Latitude            0 non-null      float64
#  28  Longitude           0 non-null      float64
#  29  Community Board     0 non-null      float64
#  30  Community Council   0 non-null      float64
#  31  Census Tract        0 non-null      float64
#  32  BIN                 0 non-null      float64
#  33  BBL                 0 non-null      float64
#  34  NTA                 0 non-null      float64
# dtypes: float64(13), int64(8), object(14)
# memory usage: 182.0+ KB

# %%
volunteer.dropna(axis=1, thresh=3).shape
# Out:
# (665, 24)

# %%
volunteer.shape
# Out:
# (665, 35)

# %% [markdown]
# ### Missing data - rows
# Taking a look at the `volunteer` dataset again, we want to drop rows where the `category_desc` column values are missing. We're going to do this using boolean indexing, by checking to see if we have any null values, and then filtering the dataset so that we only have rows with those values.

# %%
# Check how many values are missing in the category_desc column
print(volunteer['category_desc'].isnull().sum())

# Subset the volunteer dataset
volunteer_subset = volunteer[volunteer['category_desc'].notnull()]

# Print out the shape of the subset
print(volunteer_subset.shape)
# Out:
# 48
# (617, 35)

# %% [markdown]
# ### Working with data types
# - dtypes in pandas
#     - object: string/mixed types
#     - int64: integer
#     - float64: float
#     - datetime64 (or timedelta): datetime

# %% [markdown]
# ### Exploring data types
# Taking another look at the dataset comprised of volunteer information from New York City, we want to know what types we'll be working with as we start to do more preprocessing.

# %%
volunteer.dtypes
# Out:
# opportunity_id          int64
# content_id              int64
# vol_requests            int64
# event_time              int64
# title                  object
# hits                    int64
# summary                object
# is_priority            object
# category_id           float64
# category_desc          object
# amsl                  float64
# amsl_unit             float64
# org_title              object
# org_content_id          int64
# addresses_count         int64
# locality               object
# region                 object
# postalcode            float64
# primary_loc           float64
# display_url            object
# recurrence_type        object
# hours                   int64
# created_date           object
# last_modified_date     object
# start_date_date        object
# end_date_date          object
# status                 object
# Latitude              float64
# Longitude             float64
# Community Board       float64
# Community Council     float64
# Census Tract          float64
# BIN                   float64
# BBL                   float64
# NTA                   float64
# dtype: object

# %% [markdown]
# ### Converting a column type
# If you take a look at the `volunteer` dataset types, you'll see that the column `hits` is type `object`. But, if you actually look at the column, you'll see that it consists of integers. Let's convert that column to type `int`.

# %%
# Print the head of the hits column
print(volunteer['hits'].head())

# Convert the hits column to type int
volunteer['hits'] = volunteer['hits'].astype(int)

# Look at the dtypes of the dataset
print(volunteer.dtypes)
# Out:
# 0    737
# 1     22
# 2     62
# 3     14
# 4     31
# Name: hits, dtype: int64
# opportunity_id          int64
# content_id              int64
# vol_requests            int64
# event_time              int64
# title                  object
# hits                    int64
# summary                object
# is_priority            object
# category_id           float64
# category_desc          object
# amsl                  float64
# amsl_unit             float64
# org_title              object
# org_content_id          int64
# addresses_count         int64
# locality               object
# region                 object
# postalcode            float64
# primary_loc           float64
# display_url            object
# recurrence_type        object
# hours                   int64
# created_date           object
# last_modified_date     object
# start_date_date        object
# end_date_date          object
# status                 object
# Latitude              float64
# Longitude             float64
# Community Board       float64
# Community Council     float64
# Census Tract          float64
# BIN                   float64
# BBL                   float64
# NTA                   float64
# dtype: object

# %% [markdown]
# ### Class distribution
# - Stratified sampling
#     - A way of sampling that takes into account the distribution of classes or features in your dataset

# %% [markdown]
# ### Class imbalance
# In the `volunteer` dataset, we're thinking about trying to predict the `category_desc` variable using the other features in the dataset. First, though, we need to know what the class distribution (and imbalance) is for that label.

# %%
volunteer['category_desc'].value_counts()
# Out:
# category_desc
# Strengthening Communities    307
# Helping Neighbors in Need    119
# Education                     92
# Health                        52
# Environment                   32
# Emergency Preparedness        15
# Name: count, dtype: int64

# %% [markdown]
# ### Stratified sampling
# We know that the distribution of variables in the `category_desc` column in the volunteer dataset is uneven. If we wanted to train a model to try to predict `category_desc`, we would want to train the model on a sample of data that is representative of the entire dataset. Stratified sampling is a way to achieve this.

# %%
from sklearn.model_selection import train_test_split

# Create a data with all columns except category_desc
volunteer_X = volunteer.dropna(subset=['category_desc'], axis=0)

# Create a category_desc labels dataset
volunteer_y = volunteer.dropna(subset=['category_desc'], axis=0)[['category_desc']]

# Use stratified sampling to split up the dataset according to the volunteer_y dataset
X_train, X_test, y_train, y_test = train_test_split(volunteer_X, volunteer_y, stratify=volunteer_y)

# Print out the category_desc counts on the training y labels
print(y_train['category_desc'].value_counts())
# Out:
# category_desc
# Strengthening Communities    230
# Helping Neighbors in Need     89
# Education                     69
# Health                        39
# Environment                   24
# Emergency Preparedness        11
# Name: count, dtype: int64

# %% [markdown]
# > Warning: stratify sampling on `train_test_split` cannot handle the `NaN` data, so you need to drop NaN values before sampling

# %% [markdown]
# ## Chapter 2 - Standardizing Data
# > This chapter is all about standardizing data. Often a model will make some assumptions about the distribution or scale of your features. Standardization is a way to make your data fit these assumptions and improve the algorithm's performance. This is the Summary of lecture "Preprocessing for Machine Learning in Python", via datacamp.
#
# - toc: true
# - badges: true
# - comments: true
# - author: Chanseok Kang
# - categories: [Python, Datacamp, Machine_Learning]
# - image:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Standardizing Data
# - Standardization
#     - Preprocessing method used to transform continuous data to make it look normally distributed
#     - Scikit-learn models assume normally distributed data
#         - Log normalization
#         - feature Scaling
# - When to standardize: models
#     - Model in linear space
#     - Dataset features have high variance
#     - Dataset features are continuous and on different scales
#     - Linearity assumptions

# %% [markdown]
# ### Modeling without normalizing
# Let's take a look at what might happen to your model's accuracy if you try to model data without doing some sort of standardization first. Here we have a subset of the wine dataset. One of the columns, `Proline`, has an extremely high variance compared to the other columns. This is an example of where a technique like log normalization would come in handy, which you'll learn about in the next section.
#
# The scikit-learn model training process should be familiar to you at this point, so we won't go too in-depth with it. You already have a k-nearest neighbors model available (`knn`) as well as the `X` and `y` sets you need to fit and score on.

# %%
wine = pd.read_csv('wine_types.csv')
wine.head()
# Out:
#    Type  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0     1    14.23        1.71  2.43               15.6        127
# 1     1    13.20        1.78  2.14               11.2        100
# 2     1    13.16        2.36  2.67               18.6        101
# 3     1    14.37        1.95  2.50               16.8        113
# 4     1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185
# 3             7.80  0.86                          3.45     1480
# 4             4.32  1.04                          2.93      735

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

X = wine[['Proline', 'Total phenols', 'Hue', 'Nonflavanoid phenols']]
y = wine['Type']

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y, random_state=42)

knn = KNeighborsClassifier()

# Fit the knn model to the training data
knn.fit(X_train, y_train)

# Score the model on the test data
print(knn.score(X_test, y_test))
# Out:
# 0.6888888888888889

# %% [markdown]
# ### Log normalization method
# - Applies log transformation
# - Natural log using the constant $e$ (2.718)
# - Captures relative changes, the magnitude of change, and keeps everything in the positive space

# %% [markdown]
# ### Checking the variance
# Check the variance of the columns in the `wine` dataset.

# %%
wine.describe()
# Out:
#              Type     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       178.000000       178.000000  178.000000
# mean          1.590899         5.058090    0.957449
# std           0.572359         2.318286    0.228572
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.220000    0.782500
# 50%           1.555000         4.690000    0.965000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        OD280/OD315 of diluted wines      Proline
# count                    178.000000   178.000000
# mean                       2.611685   746.893258
# std                        0.709990   314.907474
# min                        1.270000   278.000000
# 25%                        1.937500   500.500000
# 50%                        2.780000   673.500000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000

# %% [raw]
# The `Proline` column has an extremely high variance.

# %% [markdown]
# ### Log normalization in Python
# Now that we know that the `Proline` column in our wine dataset has a large amount of variance, let's log normalize it.

# %%
# Print out the variance of the Proline column
print(wine['Proline'].var())

# Apply the log normalization function to the Proline column
wine['Proline_log'] = np.log(wine['Proline'])

# Check the variance of the normalized Proline column
print(wine['Proline_log'].var())
# Out:
# 99166.71735542436
# 0.17231366191842012

# %% [markdown]
# ### Scaling data for feature comparison
# - Features on different scales
# - Model with linear characteristics
# - Center features around 0 and transform to unit variance(1)
# - Transforms to approximately normal distribution

# %% [markdown]
# ### Scaling data - investigating columns
# We want to use the `Ash`, `Alcalinity of ash`, and `Magnesium` columns in the `wine` dataset to train a linear model, but it's possible that these columns are all measured in different ways, which would bias a linear model. Using `describe()` to return descriptive statistics about this dataset, which of the following statements are true about the scale of data in these columns?

# %%
wine[['Ash', 'Alcalinity of ash', 'Magnesium']].describe()
# Out:
#               Ash  Alcalinity of ash   Magnesium
# count  178.000000         178.000000  178.000000
# mean     2.366517          19.494944   99.741573
# std      0.274344           3.339564   14.282484
# min      1.360000          10.600000   70.000000
# 25%      2.210000          17.200000   88.000000
# 50%      2.360000          19.500000   98.000000
# 75%      2.557500          21.500000  107.000000
# max      3.230000          30.000000  162.000000

# %% [markdown]
# ### Scaling data - standardizing columns
# Since we know that the `Ash`, `Alcalinity of ash`, and `Magnesium` columns in the `wine` dataset are all on different scales, let's standardize them in a way that allows for use in a linear model.

# %%
from sklearn.preprocessing import StandardScaler

# Create the scaler
ss = StandardScaler()

# Take a subset of the DataFrame you want to scale
wine_subset = wine[['Ash', 'Alcalinity of ash', 'Magnesium']]

print(wine_subset.iloc[:3])

# Apply the scaler to the DataFrame subset
wine_subset_scaled = ss.fit_transform(wine_subset)

print(wine_subset_scaled[:3])
# Out:
#     Ash  Alcalinity of ash  Magnesium
# 0  2.43               15.6        127
# 1  2.14               11.2        100
# 2  2.67               18.6        101
# [[ 0.23205254 -1.16959318  1.91390522]
#  [-0.82799632 -2.49084714  0.01814502]
#  [ 1.10933436 -0.2687382   0.08835836]]

# %% [markdown]
# ### Standardized data and modeling

# %% [markdown]
# ### KNN on non-scaled data
# Let's first take a look at the accuracy of a K-nearest neighbors model on the `wine` dataset without standardizing the data. The `knn` model as well as the `X` and `y` data and labels sets have been created already. Most of this process of creating models in scikit-learn should look familiar to you.

# %%
wine = pd.read_csv('wine_types.csv')

X = wine.drop('Type', axis=1)
y = wine['Type'] 

knn = KNeighborsClassifier()

# %%
# Split the dataset and labels into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Fit the k-nearest neighbors model to the training data
knn.fit(X_train, y_train)

# Score the model on the test data
print(knn.score(X_test, y_test))
# Out:
# 0.7555555555555555

# %% [markdown]
# ### KNN on scaled data
# The accuracy score on the unscaled wine dataset was decent, but we can likely do better if we scale the dataset. The process is mostly the same as the previous exercise, with the added step of scaling the data.

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# Instantiate a StandardScaler
scaler = StandardScaler()

# Scale the training and test features
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create a K-nearest neighbors model instance
knn = KNeighborsClassifier()

# Fit the k-nearest neighbors model to the training data
knn.fit(X_train_scaled, y_train)

# Score the model on the test data
print(knn.score(X_test_scaled, y_test))
# Out:
# 0.9333333333333333

# %% [markdown]
# ## **Chapter 3 - Feature Engineering**
#
# [Link ref:](https://gist.github.com/vidit0210/c2f74323c8d2096729000f98ffbee4ac)

# %% [markdown]
# Encoding categorical variables - binary

# %%
from sklearn.preprocessing import LabelEncoder

hiking = pd.read_json('hiking.json')

# Set up the LabelEncoder object
enc = LabelEncoder()

# Apply the encoding to the "Accessible" column
hiking['Accessible_enc'] = enc.fit_transform(hiking['Accessible'])

# Compare the two columns
print(hiking[['Accessible', 'Accessible_enc']].head())
# Out:
#   Accessible  Accessible_enc
# 0          Y               1
# 1          N               0
# 2          N               0
# 3          N               0
# 4          N               0

# %% [markdown]
# Encoding categorical variables - one-hot

# %%
# Transform the category_desc column
category_enc = pd.get_dummies(volunteer["category_desc"])

# Take a look at the encoded columns
print(category_enc.head())
# Out:
#    Education  Emergency Preparedness  Environment  Health  \
# 0      False                   False        False   False
# 1      False                   False        False   False
# 2      False                   False        False   False
# 3      False                   False        False   False
# 4      False                   False         True   False
#
#    Helping Neighbors in Need  Strengthening Communities
# 0                      False                      False
# 1                      False                       True
# 2                      False                       True
# 3                      False                       True
# 4                      False                      False

# %% [markdown]
# Aggregating numerical features

# %%
import pandas as pd  

running_times_5k = pd.read_csv('running_times_5k.csv')
print(running_times_5k.head(2))
# Out:
#    name  run1  run2  run3  run4  run5
# 0   Sue  20.1  18.5  19.6  20.3  18.3
# 1  Mark  16.5  17.1  16.9  17.6  17.3

# %%
# Use .loc to create a mean column
running_times_5k["mean"] = running_times_5k[['run1', 'run2', 'run3', 'run4', 'run5']].mean(axis=1)

# Take a look at the results
print(running_times_5k.head(2))
# Out:
#    name  run1  run2  run3  run4  run5   mean
# 0   Sue  20.1  18.5  19.6  20.3  18.3  19.36
# 1  Mark  16.5  17.1  16.9  17.6  17.3  17.08

# %% [markdown]
# Extracting string patterns

# %%
import re
import pandas as pd

# Assuming "hiking.json" is a valid JSON file
hiking = pd.read_json("hiking.json")

# Write a pattern to extract numbers and decimals
def return_mileage(length):
    pattern = re.compile(r"\d+\.\d+")
    
    # Search the text for matches
    mile = re.search(pattern, str(length))  # Ensure 'length' is converted to a string
    
    # If a value is returned, use group(0) to return the found value
    if mile is not None:
        return float(mile.group(0))

# Apply the function to the Length column and take a look at both columns
hiking["Length_num"] = hiking["Length"].apply(lambda row: return_mileage(row))
print(hiking[["Length", "Length_num"]].head())
# Out:
#        Length  Length_num
# 0   0.8 miles        0.80
# 1    1.0 mile        1.00
# 2  0.75 miles        0.75
# 3   0.5 miles        0.50
# 4   0.5 miles        0.50

# %% [markdown]
# Vectorizing text

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Read the CSV file into a DataFrame
volunteer = pd.read_csv('volunteer_opportunities.csv')

# Extract the 'title' column, which presumably contains textual information
title_text = volunteer["title"]

# Create an instance of the TfidfVectorizer
tfidf_vec = TfidfVectorizer()

# Transform the textual data into TF-IDF vectors
text_tfidf = tfidf_vec.fit_transform(title_text)

# Print the resulting TF-IDF matrix
print(text_tfidf)
# Out:
#   (0, 375)	0.3163915503784279
#   (0, 855)	0.38192461589865456
#   (0, 493)	0.3405778550191958
#   (0, 822)	0.38192461589865456
#   (0, 959)	0.38192461589865456
#   (0, 1061)	0.25544926998167106
#   (0, 869)	0.38192461589865456
#   (0, 404)	0.15529778130809513
#   (0, 690)	0.24072387702158726
#   (0, 1086)	0.2304728774077965
#   (1, 297)	0.6824588570832413
#   (1, 1095)	0.7309240099960025
#   (2, 868)	0.3903159429478348
#   (2, 587)	0.4150336487706769
#   (2, 98)	0.2225785986760572
#   (2, 930)	0.35917531643639333
#   (2, 515)	0.3903159429478348
#   (2, 43)	0.4150336487706769
#   (2, 1063)	0.4150336487706769
#   (3, 710)	0.2056446046212042
#   (3, 523)	0.18207403700074992
#   (3, 255)	0.295432987618702
#   (3, 31)	0.31414199966461376
#   (3, 739)	0.31414199966461376
#   (3, 1012)	0.16847136678616276
#   :	:
#   (660, 711)	0.5093842109879203
#   (660, 402)	0.45423880718111764
#   (660, 808)	0.39909340337431487
#   (660, 1084)	0.19657602494096119
#   (660, 404)	0.20712526636615075
#   (661, 979)	0.4701913038392676
#   (661, 548)	0.4701913038392676
#   (661, 893)	0.40690944178220845
#   (661, 505)	0.39431775313392914
#   (661, 721)	0.40690944178220845
#   (661, 1086)	0.26683927283713627
#   (662, 1042)	0.6771429571509976
#   (662, 413)	0.7358514901668693
#   (663, 44)	0.780448504588674
#   (663, 637)	0.5573799263194631
#   (663, 1084)	0.28324503423963576
#   (664, 1129)	0.420727783674435
#   (664, 646)	0.420727783674435
#   (664, 394)	0.420727783674435
#   (664, 532)	0.3778928580737508
#   (664, 714)	0.33505793247306653
#   (664, 1107)	0.2671661816748015
#   (664, 484)	0.24938808127169815
#   (664, 1025)	0.23876812467897954
#   (664, 1084)	0.1526930409780694

# %% [markdown]
# Text classification using tf/idf vectors

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# Read the CSV file into a DataFrame
volunteer = pd.read_csv('volunteer_opportunities.csv')

# Drop rows with missing values in the 'category_desc' column
volunteer = volunteer.dropna(subset=['category_desc'])

# Split the dataset according to the class distribution of category_desc
y = volunteer["category_desc"]

# Create the TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()

# Transform the text data into TF-IDF vectors
text_tfidf = tfidf_vectorizer.fit_transform(volunteer["title"])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(text_tfidf.toarray(), y, stratify=y, random_state=42)

# Create a Multinomial Naive Bayes model
nb = MultinomialNB()

# Fit the model to the training data
nb.fit(X_train, y_train)

# Print out the model's accuracy
print(nb.score(X_test, y_test))
# Out:
# 0.5548387096774193

# %% [markdown]
# ## **Chapter 4 - Selecting Features for Modeling**

# %% [markdown]
# Selecting relevant features

# %%
# Create a list of redundant column names to drop
to_drop = ["category_desc", "created_date", "locality", "region", "vol_requests"]

# Drop those columns from the dataset
volunteer_subset = volunteer.drop(to_drop, axis=1)

# Print out the head of volunteer_subset
print(volunteer_subset.head())
# Out:
#    opportunity_id  content_id  event_time  \
# 1            5008       37036           0
# 2            5016       37143           0
# 3            5022       37237           0
# 4            5055       37425           0
# 5            5056       37426           0
#
#                                                title  hits  \
# 1                                       Web designer    22
# 2      Urban Adventures - Ice Skating at Lasker Rink    62
# 3  Fight global hunger and support women farmers ...    14
# 4                                      Stop 'N' Swap    31
# 5                               Queens Stop 'N' Swap   135
#
#                                              summary is_priority  category_id  \
# 1             Build a website for an Afghan business         NaN          1.0
# 2  Please join us and the students from Mott Hall...         NaN          1.0
# 3  The Oxfam Action Corps is a group of dedicated...         NaN          1.0
# 4  Stop 'N' Swap reduces NYC's waste by finding n...         NaN          4.0
# 5  Stop 'N' Swap reduces NYC's waste by finding n...         NaN          4.0
#
#    amsl  amsl_unit  ...     end_date_date    status  Latitude  Longitude  \
# 1   NaN        NaN  ...  February 01 2011  approved       NaN        NaN
# 2   NaN        NaN  ...   January 29 2011  approved       NaN        NaN
# 3   NaN        NaN  ...     March 31 2012  approved       NaN        NaN
# 4   NaN        NaN  ...  February 05 2011  approved       NaN        NaN
# 5   NaN        NaN  ...  February 12 2011  approved       NaN        NaN
#
#    Community Board Community Council  Census Tract  BIN BBL NTA
# 1              NaN                NaN          NaN  NaN NaN NaN
# 2              NaN                NaN          NaN  NaN NaN NaN
# 3              NaN                NaN          NaN  NaN NaN NaN
# 4              NaN                NaN          NaN  NaN NaN NaN
# 5              NaN                NaN          NaN  NaN NaN NaN
#
# [5 rows x 30 columns]

# %% [markdown]
# Checking for correlated features

# %%
wine = pd.read_csv('wine_types.csv')

# Print out the column correlations of the wine dataset
print(wine.corr())

# Take a minute to find the column where the correlation value is greater than 0.75 at least twice
to_drop = "Flavanoids"

# Drop that column from the DataFrame
wine = wine.drop(to_drop, axis=1)
# Out:
#                                   Type   Alcohol  Malic acid       Ash  \
# Type                          1.000000 -0.328222    0.437776 -0.049643
# Alcohol                      -0.328222  1.000000    0.094397  0.211545
# Malic acid                    0.437776  0.094397    1.000000  0.164045
# Ash                          -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash             0.517859 -0.310235    0.288500  0.443367
# Magnesium                    -0.209179  0.270798   -0.054575  0.286587
# Total phenols                -0.719163  0.289101   -0.335167  0.128980
# Flavanoids                   -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols          0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins              -0.499130  0.136698   -0.220746  0.009652
# Color intensity               0.265668  0.546364    0.248985  0.258887
# Hue                          -0.617369 -0.071747   -0.561296 -0.074667
# OD280/OD315 of diluted wines -0.788230  0.072343   -0.368710  0.003911
# Proline                      -0.633717  0.643720   -0.192011  0.223626
#
#                               Alcalinity of ash  Magnesium  Total phenols  \
# Type                                   0.517859  -0.209179      -0.719163
# Alcohol                               -0.310235   0.270798       0.289101
# Malic acid                             0.288500  -0.054575      -0.335167
# Ash                                    0.443367   0.286587       0.128980
# Alcalinity of ash                      1.000000  -0.083333      -0.321113
# Magnesium                             -0.083333   1.000000       0.214401
# Total phenols                         -0.321113   0.214401       1.000000
# Flavanoids                            -0.351370   0.195784       0.864564
# Nonflavanoid phenols                   0.361922  -0.256294      -0.449935
# Proanthocyanins                       -0.197327   0.236441       0.612413
# Color intensity                        0.018732   0.199950      -0.055136
# Hue                                   -0.273955   0.055398       0.433681
# OD280/OD315 of diluted wines          -0.276769   0.066004       0.699949
# Proline                               -0.440597   0.393351       0.498115
#
#                               Flavanoids  Nonflavanoid phenols  \
# Type                           -0.847498              0.489109
# Alcohol                         0.236815             -0.155929
# Malic acid                     -0.411007              0.292977
# Ash                             0.115077              0.186230
# Alcalinity of ash              -0.351370              0.361922
# Magnesium                       0.195784             -0.256294
# Total phenols                   0.864564             -0.449935
# Flavanoids                      1.000000             -0.537900
# Nonflavanoid phenols           -0.537900              1.000000
# Proanthocyanins                 0.652692             -0.365845
# Color intensity                -0.172379              0.139057
# Hue                             0.543479             -0.262640
# OD280/OD315 of diluted wines    0.787194             -0.503270
# Proline                         0.494193             -0.311385
#
#                               Proanthocyanins  Color intensity       Hue  \
# Type                                -0.499130         0.265668 -0.617369
# Alcohol                              0.136698         0.546364 -0.071747
# Malic acid                          -0.220746         0.248985 -0.561296
# Ash                                  0.009652         0.258887 -0.074667
# Alcalinity of ash                   -0.197327         0.018732 -0.273955
# Magnesium                            0.236441         0.199950  0.055398
# Total phenols                        0.612413        -0.055136  0.433681
# Flavanoids                           0.652692        -0.172379  0.543479
# Nonflavanoid phenols                -0.365845         0.139057 -0.262640
# Proanthocyanins                      1.000000        -0.025250  0.295544
# Color intensity                     -0.025250         1.000000 -0.521813
# Hue                                  0.295544        -0.521813  1.000000
# OD280/OD315 of diluted wines         0.519067        -0.428815  0.565468
# Proline                              0.330417         0.316100  0.236183
#
#                               OD280/OD315 of diluted wines   Proline
# Type                                             -0.788230 -0.633717
# Alcohol                                           0.072343  0.643720
# Malic acid                                       -0.368710 -0.192011
# Ash                                               0.003911  0.223626
# Alcalinity of ash                                -0.276769 -0.440597
# Magnesium                                         0.066004  0.393351
# Total phenols                                     0.699949  0.498115
# Flavanoids                                        0.787194  0.494193
# Nonflavanoid phenols                             -0.503270 -0.311385
# Proanthocyanins                                   0.519067  0.330417
# Color intensity                                  -0.428815  0.316100
# Hue                                               0.565468  0.236183
# OD280/OD315 of diluted wines                      1.000000  0.312761
# Proline                                           0.312761  1.000000

# %% [markdown]
# Exploring text vectors, part 1

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# Example data
data = [
    'web designer',
    'urban design',
    'graphic designer',
    'software developer',
    'urban planning',
    'web developer',
    'architect',
    'interior designer',
    'urban gardening',
    'web development'
]

# Example vocabulary
vocab = {
    'web': 0,
    'designer': 1,
    'urban': 2,
    'graphic': 3,
    'software': 4,
    'developer': 5,
    'planning': 6,
    'architect': 7,
    'interior': 8,
    'gardening': 9
}

# Create the TfidfVectorizer with the provided vocabulary
tfidf_vec = TfidfVectorizer(vocabulary=vocab)

# Transform the text data into TF-IDF vectors
text_tfidf = tfidf_vec.fit_transform(data)

# Convert the sparse matrix to a dense matrix for easier inspection
dense_matrix = text_tfidf.toarray()

# Display the dense matrix
df = pd.DataFrame(dense_matrix, columns=tfidf_vec.get_feature_names_out())
print(df)
# Out:
#         web  designer     urban   graphic  software  developer  planning  \
# 0  0.707107  0.707107  0.000000  0.000000  0.000000   0.000000  0.000000
# 1  0.000000  0.000000  1.000000  0.000000  0.000000   0.000000  0.000000
# 2  0.000000  0.596775  0.000000  0.802409  0.000000   0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.761905   0.647689  0.000000
# 4  0.000000  0.000000  0.596775  0.000000  0.000000   0.000000  0.802409
# 5  0.658454  0.000000  0.000000  0.000000  0.000000   0.752621  0.000000
# 6  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 7  0.000000  0.596775  0.000000  0.000000  0.000000   0.000000  0.000000
# 8  0.000000  0.000000  0.596775  0.000000  0.000000   0.000000  0.000000
# 9  1.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
#
#    architect  interior  gardening
# 0        0.0  0.000000   0.000000
# 1        0.0  0.000000   0.000000
# 2        0.0  0.000000   0.000000
# 3        0.0  0.000000   0.000000
# 4        0.0  0.000000   0.000000
# 5        0.0  0.000000   0.000000
# 6        1.0  0.000000   0.000000
# 7        0.0  0.802409   0.000000
# 8        0.0  0.000000   0.802409
# 9        0.0  0.000000   0.000000

# %%
# Create the TfidfVectorizer with the provided vocabulary
tfidf_vec = TfidfVectorizer(vocabulary=vocab)

# Transform the text data into TF-IDF vectors
text_tfidf = tfidf_vec.fit_transform(data)

# Adjust the original_vocab dictionary to map words to indices
original_vocab = {v: i for i, v in enumerate(tfidf_vec.get_feature_names_out())}

# Add in the rest of the parameters
def return_weights(vocab, original_vocab, vector, vector_index, top_n):
    zipped = dict(zip(vector[vector_index].indices, vector[vector_index].data))

    # Print the indices for debugging
    print("Indices in the sparse matrix:", vector[vector_index].indices)
    
    # Let's transform that zipped dict into a series
    zipped_series = pd.Series({original_vocab[i]: zipped[i] for i in vector[vector_index].indices if i in original_vocab})
    
    # Print the zipped_series for debugging
    print("Zipped series:", zipped_series)
    
    # Let's sort the series to pull out the top n weighted words
    zipped_index = zipped_series.sort_values(ascending=False)[:top_n].index
    return zipped_index

# Print out the weighted words
print(return_weights(vocab, original_vocab, text_tfidf, vector_index=8, top_n=3))
# Out:
# Indices in the sparse matrix: [9 2]
# Zipped series: Series([], dtype: object)
# RangeIndex(start=0, stop=0, step=1)

# %% [markdown]
# Exploring text vectors, part 2

# %%
def words_to_filter(vocab, original_vocab, vector, top_n):
    filter_list = []
    for i in range(0, vector.shape[0]):
    
        # Call the return_weights function and extend filter_list
        filtered = return_weights(vocab, original_vocab, vector, i, top_n)
        filter_list.extend(filtered)
        
    # Return the list in a set, so we don't get duplicate word indices
    return set(filter_list)

# Call the function to get the list of word indices
filtered_words = words_to_filter(vocab, tfidf_vec.vocabulary_, text_tfidf, 3)

# Filter the columns in text_tfidf to only those in filtered_words
filtered_text = text_tfidf[:, list(filtered_words)]
# Out:
# Indices in the sparse matrix: [1 0]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3 1]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [5 4]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [6 2]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [5 0]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [7]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [8 1]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [9 2]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [0]
# Zipped series: Series([], dtype: object)

# %% [markdown]
# Training Naive Bayes with feature selection

# %%
# Split the dataset according to the class distribution of category_desc
X_train, X_test, y_train, y_test = train_test_split(filtered_text.toarray(), y, stratify=y, random_state=42)

# Fit the model to the training data
nb.fit(X_train, y_train)

# Print out the model's accuracy
print(nb.score(X_test, y_test))

# %% [markdown]
# Using PCA

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import pandas as pd

# Assuming 'wine' is your DataFrame
# Instantiate a PCA object
pca = PCA()

# Define the features and labels from the wine dataset
X = wine.drop("Type", axis=1)
y = wine["Type"]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)

# Apply PCA to the wine dataset X vector
pca_X_train = pca.fit_transform(X_train)
pca_X_test = pca.transform(X_test)  # Use transform, not fit_transform, on the test set

# Look at the percentage of variance explained by the different components
print(pca.explained_variance_ratio_)
# Out:
# [9.97802349e-01 2.02071713e-03 9.82348559e-05 5.53994004e-05
#  1.10395648e-05 5.87233448e-06 3.13858204e-06 1.54420449e-06
#  1.02927386e-06 3.90521513e-07 1.95535151e-07 8.99659634e-08]

# %% [markdown]
# Training a model with PCA

# %%
# Fit knn to the training data
knn.fit(pca_X_train, y_train)

# Score knn on the test data and print it out
print(knn.score(pca_X_test, y_test))
# Out:
# 0.7777777777777778

# %% [markdown]
# ## **Chapter 5 - Putting It All Together**

# %% [markdown]
# Checking column types

# %%
ufo = pd.read_csv('ufo_sightings_large.csv')
print(ufo.head(4))
# Out:
#                date         city state country      type    seconds  \
# 0   11/3/2011 19:21    woodville    wi      us   unknown  1209600.0
# 1   10/3/2004 19:05    cleveland    oh      us    circle       30.0
# 2   9/25/2009 21:00  coon rapids    mn      us     cigar        0.0
# 3  11/21/2002 05:45     clemmons    nc      us  triangle      300.0
#
#     length_of_time                                               desc  \
# 0          2 weeks  Red blinking objects similar to airplanes or s...
# 1           30sec.               Many fighter jets flying towards UFO
# 2              NaN  Green&#44 red&#44 and blue pulses of light tha...
# 3  about 5 minutes  It was a large&#44 triangular shaped flying ob...
#
#      recorded         lat       long
# 0  12/12/2011  44.9530556 -92.291111
# 1  10/27/2004  41.4994444 -81.695556
# 2  12/12/2009  45.1200000 -93.287500
# 3  12/23/2002  36.0213889 -80.382222

# %%
# Print the DataFrame info
print(ufo.info())

# Change the type of seconds to float
ufo["seconds"] = ufo["seconds"].astype(float)

# Change the date column to type datetime
ufo["date"] = pd.to_datetime(ufo["date"])

# Check the column types
print(ufo.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4935 entries, 0 to 4934
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4935 non-null   datetime64[ns]
#  1   city            4926 non-null   object
#  2   state           4516 non-null   object
#  3   country         4255 non-null   object
#  4   type            4776 non-null   object
#  5   seconds         4935 non-null   float64
#  6   length_of_time  4792 non-null   object
#  7   desc            4932 non-null   object
#  8   recorded        4935 non-null   object
#  9   lat             4935 non-null   object
#  10  long            4935 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 424.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4935 entries, 0 to 4934
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            4935 non-null   datetime64[ns]
#  1   city            4926 non-null   object
#  2   state           4516 non-null   object
#  3   country         4255 non-null   object
#  4   type            4776 non-null   object
#  5   seconds         4935 non-null   float64
#  6   length_of_time  4792 non-null   object
#  7   desc            4932 non-null   object
#  8   recorded        4935 non-null   object
#  9   lat             4935 non-null   object
#  10  long            4935 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 424.2+ KB
# None

# %% [markdown]
# Dropping missing data

# %%
# Check how many values are missing in the length_of_time, state, and type columns
print(ufo[["length_of_time", "state", "type"]].isnull().sum())

# Keep only rows where length_of_time, state, and type are not null
ufo_no_missing = ufo[ufo["length_of_time"].notnull() & 
          ufo["state"].notnull() & 
          ufo["type"].notnull()]

# Print out the shape of the new dataset
print(ufo_no_missing.shape)
# Out:
# length_of_time    0
# state             0
# type              0
# dtype: int64
# (1866, 12)

# %% [markdown]
# Extracting numbers from strings

# %%
def return_minutes(time_string):

    pattern = re.compile(r'\d+')
    # Search for numbers in time_string
    num = re.search(pattern, time_string)
    if num is not None:
        return int(num.group(0))
        
# Apply the extraction to the length_of_time column
ufo['minutes'] = ufo['length_of_time'].apply(lambda row: return_minutes(row))

# Take a look at the head of both of the columns
print(ufo[['length_of_time', 'minutes']].head(10))
# Out:
#     length_of_time  minutes
# 0  about 5 minutes      5.0
# 1       10 minutes     10.0
# 2        2 minutes      2.0
# 3        2 minutes      2.0
# 4        5 minutes      5.0
# 5       10 minutes     10.0
# 6        5 minutes      5.0
# 7        5 minutes      5.0
# 8        5 minutes      5.0
# 9          1minute      1.0

# %% [markdown]
# Identifying features for standardization

# %%
# Check the variance of the seconds and minutes columns
print(ufo[['seconds', 'minutes']].var())

# Log normalize the seconds column
ufo['seconds_log'] = np.log(ufo['seconds'])

# Print out the variance of just the seconds_log column
print(ufo['seconds_log'].var())

# %% [markdown]
# Encoding categorical variables

# %%
# Use Pandas to encode us values as 1 and others as 0
ufo['country_enc'] = ufo['country'].apply(lambda x: 1 if x == 'us' else 0)

# Print the number of unique type values
print(len(ufo['type'].unique()))

# Create a one-hot encoded set of the type values
type_set = pd.get_dummies(ufo['type'])

# Concatenate this set back to the ufo DataFrame
ufo = pd.concat([ufo, type_set], axis=1)
# Out:
# 21

# %% [markdown]
# Features from dates

# %%
# Look at the first 5 rows of the date column
print(ufo['date'].head(5))

# Extract the month from the date column
ufo['month'] = ufo['date'].apply(lambda date: date.month)

# Extract the year from the date column
ufo['year'] = ufo['date'].apply(lambda date: date.year)

# Take a look at the head of all three columns
print(ufo[['date', 'month', 'year']].head())
# Out:
# 0   2002-11-21 05:45:00
# 1   2012-06-16 23:00:00
# 2   2013-06-09 00:00:00
# 3   2013-04-26 23:27:00
# 4   2013-09-13 20:30:00
# Name: date, dtype: datetime64[ns]
#                  date  month  year
# 0 2002-11-21 05:45:00     11  2002
# 1 2012-06-16 23:00:00      6  2012
# 2 2013-06-09 00:00:00      6  2013
# 3 2013-04-26 23:27:00      4  2013
# 4 2013-09-13 20:30:00      9  2013

# %% [markdown]
# Text vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Take a look at the head of the desc field
print(ufo['desc'].head())

# Create the tfidf vectorizer object
vec = TfidfVectorizer()

# Use vec's fit_transform method on the desc field
desc_tfidf = vec.fit_transform(ufo['desc'])

# Look at the number of columns this creates
print(desc_tfidf.shape)
# Out:
# 0    It was a large&#44 triangular shaped flying ob...
# 1    Dancing lights that would fly around and then ...
# 2    Brilliant orange light or chinese lantern at o...
# 3    Bright red light moving north to north west fr...
# 4    North-east moving south-west. First 7 or so li...
# Name: desc, dtype: object
# (1866, 3422)

# %% [markdown]
# Selecting the ideal dataset

# %%
# Make a list of features to drop
to_drop = ['city', 'country', 'date', 'desc', 'lat','length_of_time', 'seconds', 'minutes', 'long', 'state', 'recorded']

# Drop those features
ufo_dropped = ufo.drop(to_drop, axis=1)

# Let's also filter some words out of the text vector we created
filtered_words = words_to_filter(vocab, vec.vocabulary_, desc_tfidf, top_n=4)
# Out:
# Indices in the sparse matrix: [2134 1320 2657 3123  147 1744 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1787 2173 1645 1923 3007  340  395 1319 3379 3002 1794  910]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  92  251 1690 1942 2176 2130  273 3298 3050 1102 2021 1363   15 3001
#  1774  412 1738  718 2184 2188  604 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 766  502 1003 3041 1539 3003 1360 2097 2472  596 3298 3050 2021 1787
#  1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2094 2330 2107 2943 3296 3015 2899 1063 1462  873 2766 1276 2793 2097
#  3298 1102 2021 1738  718 2184 1787 3007  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2751 2157  449  596 2021 1787 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1025 3057 1915 2435 3315  351  637 1926  738 2031 2872 3003 3050 2021
#  3007  340 1794 2134  147 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1963  864 1331 3202 3280 3206 2737 1421 3153 3003 3007  395 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3077 3085 1326 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2265 1065 1543 2171 2524  401 1859 2586   46 3350 1607 3153 2157 3003
#  1320  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 259 3097  498 2623 2067 1482 2778  386 2602  249   23 2343   13 2171
#  2586 1607 1963 3003 2097 3298 3050  412 3002  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1987  691 1414 1607 2188 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2271 1240 2551 2822 1928 1607  738  596]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2262 2954  313 3312 2535  760 1530  865 1424 1656 3011 3069 1076 3287
#   401  637 2157 3296 3003 3050 2173  340  395]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2757 3081 3355 1061 1209  337 1420 2177  558  474 2158 3137 2171 2586
#  1607 2737 2751 2157 3003 1360 2472  596 2021 1787 2173]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3219 3190 2198   31  167 1337 3097 2586 1607 3015 2793 3003 2472 1102]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 764  384  811  782  628 3011 1607 1963  864 1331 2157 3296  596]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 125  750 2293 3141 3311   42 2553 2729  258 2583  784 2708  486 3355
#  2623 1607 2157 3003  395 1794 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2654 1549 2085 1572 1723  881 1808    0    4  225    8   13]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1800 3104 3390 2647 2471  536 2730 1914 2754  259  873 3003 3050 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 187 1966  524 2698 1141 3067 1032 2966 3194  627 2622 2553 3355 3057
#  2157 3050 3002 2134  147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3147 2643 1533 1312 2136 2475 2198 2822 1607  637 2157 2188 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3126 2875 2800 2013 2211 3316 2485 2940 2729 2586 1607 2872 3003  596
#  3050  412 2173 3007 3002 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3240 2263 3295 1014 2932 2329 1147 2715 1831  671 2725 3194 2754  760
#  3287 1607 3296  873 3050  412  340 1320 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 466 1332  291 2274 3380 2054  219  703 3319 3240 2583  637  147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3218 1695 2421  442  793  733 2620  652 2218 2373 3240 3295 2013 2793
#  3003 1360 2097 3050 2021  340  395 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 947  214  205  990 2224  880 1593 1483 2000 1437 2038 3022  671  258
#   337 3287 2586 1607 3296 2793 3003 3007  340  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 289  979  699 1418  442  784 2271 3097 1607 3050 2188 3007]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1556 3393 1607 2737 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1240 1607 2737 3003  596 2021 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2377 2886 2700 2367  962 1656 3153 2157 3003  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1007  987 2816 2571 3052 1796 2857 3240  760 3097  596  412  340 1794
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2980 3246  682 1954  108 2229 2705  713 1289 2038 2875 1549 2171  401
#  1331 2472  596 1363   15  340 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1252  286 1270 1032 1607 1963 2737 3003 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 929 2755 1279  970 1445 2198 1337 3355 1607 2134 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 438 2814 1555  964 2076 2229 2535 1607 3003  596  412 3007 3002 1794
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 658 1969 2229 2176 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1861 1098  357 2368 1517  477  368 1270 1796  291 3287 2586 3057  873
#  3003 2472  596 3050 3002 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2788 2084 2900 1612 1665 2816 1800 3355  337 1607 2021  412]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2210 1729  549 1297  970 1556 3319  536 3355 1607  873 2472 2184 1787
#   340 1794 2657  147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2936   35   21 2685 1365 2425  286 2857 3287 2586 1607 1787 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1719  282  943 2583 3287  401 2586  873 3002 2657 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 909 1219 2410  554 2218 1607 2737 3003 3298 3050 1787  340  395 3002
#   147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1011 2529  885 1279 1607 2751 2472  596 3007 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1770 1489 2179 2744 3337  911 2544  494 1430 2512 2076 2038 3137  401
#  1331 3003 3050 1645  340 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 489  352 1924  298 1378 2229 3355   23 2472 1787  340 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2889 2144 1324  191  770 1092 1630 2656  124  374  197 3040 1770 1556
#  3319 1800 1337  401  873   15 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 117 2999  616 1607  738 2188 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3284 2791 1611 2832 1900  549 3319 1572 3355 2586 1607 2472 2021  340
#  1794 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3005 3053 2679 1598 3308  407 1398 2168 3402  181  242  151  106  374
#  2857  337 2171 1607 2737 3003 1690  412  340 2134  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 504 2018 2425  286 2857 2872]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 133  232 1254 1020 1533 2553 2623 1607 3003 1360  273]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 702 2335 2258  117   21 2136    8 1607 2737 3003 3007  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1005  179  926  749 1088  324  366 1517 2932 1337  596  412  340 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1465 2229 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1600 1556 2623 1607  873]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1691 1907 2960 1517 2700  502]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2862 1829   78 2803 2219  749 3308 2425 1796   31 1337 1607 2737 3153
#  2157 3003 3050 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1476 2902 2088 3292  336  599 1292  368 3295 2171 2157  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2117 2525 3293  657  490 1896  457 1817 3268  549  477 2038 1831 1533
#  2623 2586 2766 1360 2472  412 1787  340 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1174  721 2236 2250  520 2403 2229 2171 1607 2737 3003 2472   92 1794
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 653  356 2572  682 2171 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2788 2084 3355  738 2472 2188  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3023 1597  857  945 2107 2134 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2200  133 2425 2084  764 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1176 2706 1306  554 3319 2737  596  273 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 998  697 2386 2506 2340 2038 3003  596  340 2134 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3184 1196 3355]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3230 3246 3355 1607 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 762  632  296 2617 1475 1053 2604  856 2525 1829 3308 2229 1796 2218
#  1831 2725 2171 3003 3050  340 1794 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3269 2446  463 2194 2171 2737 2157 3015 2472  273 2021 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1028 3409 3412  555 2225 2194 2018 2932  401  340 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 970 3246 2940 3287 1482 1607 2737  412 2134 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2746 2533 2163 2898 2229 3240 2021  340 2134 1320  147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2619 3117 2813  133 1607 2737 3003]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1822 2012  973 2605 3287  401 1607 3280 2107 2472  596 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2405 2439 1105 2403 3316 1607 2737 2793 2097  273 3050 2021 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 290 3283 2381  292 3355 2157 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2277 2717 2108 2120 1086 2922 1444 1822 2700 3393 3319 3355 1209 2157
#   596 1787  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1675 2068  863 1985 2458 1026  508 2229 3240 2136  596  340 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1455 1886  929 2700 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 670 2305  574 1273  364 3246 2136  536 1337   23 2171 1607  738 2188
#   340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2052 2436  287 1751 1080 1270 2218 1607 2737 2157  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3117 2097 2021 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1838 2216  243  377 1292 1556 2224  442  652 2373 1533 3011 3287 2623
#  2171 2157  596 1942 1787  340 2134  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2084 1796 1014 2085 1360 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1008 1996 1219 3393 2218 3147  498 1607  596 2188 1787 2173 1645 3007
#   340 3002  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1646  369  293 1948 2024  790 2836 1270 1796 3355 2822  259  596 3050
#  2184 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1447 1444  554 2229 3319  671 1312 3355 2751  873  340 1794 2657 3123
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 994 2697 1239 1354 2836 3023 2902 2168 2038 3194 3390   31 1061  313
#  3312 1607 2737 3003 2021 1787  340  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2767  445 1366 2836  292  259 2737 2157 3003  273]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1607 2737 3003  596 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1846 1165 1295 2277 2717 2108 2120 2700 2367 2872 2157 1787  340 2134
#  1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1494   98 1354 2836 2425 2038 1533    0 3355 3097  873  340  395 3123
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 690 3147 3355  738  873 3003  273 1794 2657 3123 1744 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 140   25  101  863 2706 2902 1279 2229 2013   23 2171 2472  412 2188
#   395 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1370 1860 3241 2844 2229 1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3256 2578 1989 2867 1685 2244 2617 3023 2803 2425  477 2076 1607 2737
#  3003 3050 3379 3002 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 137 2218 2198 1337 1607 2021 2188  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1105 1555  970 3355 2171 2737  873 3003  596 1794 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2592  700 3154 2068 1174 3390 1607  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2909  289  442 1360  596 3298 3050 1102  340 1794  910]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1653 1978  955 2823  368 1607 2751 2472 2021 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1677 1338  453 1948 2439 2421  703 1607  637 2157  596 2021 2188 1787
#   340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1281  775 3249  689 1702 3066 2225 2803 2136 2031 1360  596 2021 2657
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1125 2256  476 1417  632  296 2084  286 1270 2038  337 1240  401 2586
#  2107 2097 2188 2173 1320  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1198 1478 1757  612 2719  406 1457 2498  328 1751 2163  632  133  108
#  2038 3390  384 3355 1607 3003 3050  340 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2928 3031  356 2572 2229 2198 2157  596 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 570 3324  510 1269  453 2229 1556 2054 3147  524 2553 2157 2793 3003
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2076 2737 2157  449 3003 2472  596  273 2021 2188 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3059 2281 1790 1345 2344 2278 3355 2171 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2014 1164 3110 3044 3360 3031 2403 2816  733 2013 3312 2872 2157 1276
#  2021  412  340 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1314 2100 3095 2198 1607 2737 2793 3003  273 3298 3050 1102 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2408 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3185 2538 2686  296 1770  438 1796 1312  337 3312  873 3002 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 467 3025 2727 2789 1936 1254  713 2700 3355 2171  401 2157  873  596
#  1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1105  911 1312 2198 1337 1607 2737 2188  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 893 1768 2920 1295 1607 2188  604 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2746  632 1312 1607 2737  449 2021 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  29 1192 1586 2229 1695  498  596 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2231  380 1463 2824 1345 1822 2656 2425  970 2136 3355 1607 2188 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 743 2240 2487 2656 2229 1556 3393 1695  782 2822 2157 3003 2188  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 996 1325 1087 1008 2052 2068  296 2553 2708  337 2623 1607 3007  340
#  2134 1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1806  743 2229 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3034 3360 2737 2751 3003  596 2021 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2143 2134 3123]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2074 2027 3398 2111 1413 1232  593 2533 2617  749 2084 2076  291 3240
#  2171 1607 3202 2107 3003 1360 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2840 1545 1922 1292  117 3319  259  351  596]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2833 3092 2674 2773 2827 2746  697 3316 1312  536 2822 1607 1360 3050
#  2173 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 688 2781 1460  898 1340 2189 1566 1492  743 3005 1800  259  498 2623
#  2067 2586 2793 3003  596 1645 1794 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1993   36 1324 3147 2586  637  596 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3150 1269 1008  524 3287 2586  637 2751  449  596 2188  340 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1339 3031 3117 2076 1607 2737 3003 3002 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1043 1791 3286 2615 1295 1598   21 1517 2571  258 2551  401 1607 2737
#   873 3003 2021 1787 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1910  729 1354 2229 2038 1549 2586 3003  340 2134 2657 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 673 1616 1120  554 2229 3081 2097  596 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 408 2694 1981 3214  844 2609 2260 2216 2038  442 2211 3316 3355 1076
#  3287 2171 2524 1607 3296 3003  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1134  287 3005 2755 3319 2136 3011 1607 2737 2751 2157 3296 3003  596
#  2021 2173 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1441 1547 2566  927 1846 1751   78 2656 1312 2471  258 3312 1076 2343
#  2586 1607 2737 3003  596  412  147 1744 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2012 2706 1270  337 2586 2737 3003 1360  273 3298 3050 1102 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2422  805 1182  722 2671 2669 2831  882 3396  439 3023 1796 3240 3003
#   340 2134 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1746 2699 3230  964 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 198 3294 1179 2496 3023 1656 3069 1607 3153 2157 3003]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1245  141  109 3358  554 2788 1556  291 3319 3147  258 3355 1607 3003
#  2472 1787 2173  340 1794 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 441 2299 2229 1796 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3384 1405 2186 2194 2229]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  60 1227 3148 1552 1557 2229 3153  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1754 1967 2002 3199 1971 2834 2277 2108 2120 2900 3240 3355  596]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1164 3117 1324 3355  637 1787 1794 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 200 3292 1556 2421 1831 2021 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2081 1231 2010 3281 2187  996 2084 2229 2571  652 3295 2085 2553  384
#  3219 2198  313 1607 3015 3003 1360 2472  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2801 2638 3319 1607 2737 2157 3003 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3282 2985 2403 2229 1556 2623 2134 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3261  573 1301 1805 1463 2229 3355 2751 2472  596 2188 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2053 2170 1206 2911 1042 1929 1444  929 1556 1695 2822 1607 2737 2157
#  2793 3003  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 659 1487 2496 2686 1829 2803 2900 1796 2218 3067 2472  340 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 134  974 3031 2012 3393  524 2586 1607 2793 3003 3002 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 914 1553 2064 2946 1444 1954 2421 3147 1337 1061 1607  637 2472 2184
#  1787  340 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1617  112 1520 1624  785 1902  366   35 3355 2171 1607 2157  873 3298
#  1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3236  999 1521 3106  957  659 1487 2496  298 2171 2157 2793 3003 1645
#  2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3000  712 2628  633 1247  496 1361 1415 1910 3337  368 2076 2038 3319
#  1607  738 2157  412  340 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1937 1529  774 2152  414  901 1492 1314 2788 2229 1695 2054 3319 3067
#  2158 2793 2134 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 310 1447 3194  760 2623]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2339  749 1607 2737 3003 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1343  442 1607 2737 1003  596 2021 1787 3007  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1767 3221 1548 1724    5 1117 1273   78   21  368  108 3393 2932 2757
#  2171 1607 3003  596 3298  412  340 2134 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3183  560 1787 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3144 1607 2737 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 393 3168  849  689 1020 1324  911 2755 3319 2171  637  873 2472 1787
#  1794 2657 3123  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1069 2528 2321 3017 3034 1417  291 3147 3003  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  51   50 1096 2371 3210 2026 3236 3066  377 2533 1176 2054 1607 2472
#  2184 1794 1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2251  739 1472 2312 2114 1546 1265 3130 2913 2490 1345  524 1076  259
#  2171 3202 2157 3296 3003 3050 2134 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1538 3373 1490   57 2936  368 2076 3319 3097 2171  596 3298 3050 1787
#   147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3400  938 2309 2617 1331 3003  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  81   41 1904  564 1600 2700 2171 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1912 2700 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2408 3319 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2136 2472 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1771 1361 2216 1297  438 3240 2329 2013 3147 1607 2751 2157 2330 3003
#  1360  340 2134 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1345 1607 2737 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 743 2836 2229 1556  873 3003 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2494 1303 1301 2231 2194 2706 2218 3295  536  637 2188 3007 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3117  911  536  873  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1929 2822]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2923 3319 3240  738 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 478 1459 2606 1799 2238 1546 2152 2827  743 2229 2136 2171 1607 2737
#  2184  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 796  453  117 2218 2157 2472 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 404 1962 3100 1557 3034 1417 2076 3319 3194 2822 2737 2751  766  273
#  3007  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1877 1408 1929 2229 1014 2136 2708 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 503  858 2775  991  134 3154 1354 2218 3295 3316 3355 3069 1076 3287
#  2171 2586 3003 3050  340  395 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1087 2229  596 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  83 1888  342 1836 3168 1444 3117  554 3153 2472 1794 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 359 1241 1301  292  554 2084 1861 2816 3319  536 2085 3355  498 2623
#  1482 2472 1787 3007  340  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2957 2667  541  787 2029  438  286  733  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1203 3111 2716 1114 1561   93 1754 1967 2277 2108 2120 1517  873 2097
#  1102 2021  412]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1444 1517 3240 2171 1607 2737  873 3003 2472  340 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1700  276 3148 1607 3153 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2580 2277 2108 2120 1444 2368 1796 2857 3319 1607 2737 2472 2021  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 708  410 2194 2708 3355]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1270 2623 1607 2737]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1880 3192 3096 1337  337 1607 1787 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2056 3371 1959 1834 3410 2345 1343 1301 3412 2229  442  384  337 3315
#  2157 2097 1942 1787  340  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2693 2707 3063  848 1157 2773 3031 1417 3117 1092 2656  911  258 3355
#   337 2171 3003 2472 1787 2173]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2011 1021 1601  342 1836 2229 3319 1102]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1284 2902 1607 2737 3003 2188 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1208 1385 1819 2098  324 2229 2038 2800 3147 3097 2623 1607 1360 3050
#   412 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1304 3319 1337 1607 1794 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2701  934  572  950 3132 1962 1767 1417  286 2647  873  502 2472  340
#  2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2155 2521 1714 2700 2097]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2746 2084 1861 2085 2553  873 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1778  901 2064 3148 2229 3319 2751 3003 2097 3050 2021]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1760 2563 1770 2900 2857 1831 2136 1800 1337 3137 1607 3003 2097 3298
#  3007]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2565 1617 1846 2229  873 2793 3298 3050 1102 1320 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2771 2997  310]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1842  461 1047 3222  686 1364  292 1088 2258 2788 2084 2229 2966 3081
#  3296 2184 1787 2173 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1659 2276 2314 2721 2174 1287 3031 2755  637  596  412 2188 2173 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3168 2656  911 1014 2754 3355 1414 2188 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1244  420  491 3286 1566 3031 3117 2656 2229 2472 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1210 2045 1036 3389 2325 1851  657  477 2229 3355 2623 1607 1331  637
#  3003  596 3002 1794 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2015 3405 1904 1612 3246   31 3355 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1825 1839 2252 1040 3347 1281 1846 2836 2229 1556 3240 1607 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1998 3317 2081 1338  863 2647 2623 1607 1963 1331 2472 1794 3123  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1041  327  731 2760 1747 3373 2114 1829  749 3308 2076 2224 2038 3316
#  3194 2171  401 2737 2157 3003  412  340  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  65 1140 2493  258 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 483 3031 2746 2656 2084  477 2229 1556 2620 3240 1141 3355 3011 2171
#  3003 2472 3298 3050 2021 2188 1794 3123  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2359 1336 3079 2049  818 1929  477 1796 2583 3355 1530 1859 1607 2031
#  3050  340 1794  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3220 3229  645 3034 2100 2737  596 2188 1787 3007]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3099 2222 2413 1056 1885 3017  697 1829 2656 3052 1796 3319 3240 1800
#  1607 2751 3003 2097 2472 1794 2134  147 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1006 2675  286 3295 3316  764 1607 2737  502 3003  340 3002 1794 2134
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2459 3043  335 2683 1034 1442  888  322  982 1007 3194 1607 2737 2157
#  3003  596 1787 3007  340 3379 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2829  735 3044 1345 2225 3147  412 1645]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3215 2722 3261 2229  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3183 1607 2737 3003 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  72 2202  405  248 1485 2053 2010 3117  336  554  549 3319 1337 1607
#  2157 1690 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1417 2900 1270 2705 2013 1800 1607 2751 1276  412]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 862 1927 1797 2163 2446  554  733 3319  536  259 1607 3202 2472  340
#  2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2866 1520 1444 2054 2754 3355 2551 2751 2472  340 1794 2134 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3117 2656 1607 1539 2472 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 332 3052 3147  784 2198 2021]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 391 1504  475 2326 2044 1280  262  233  224 1765  477  368 3319 3194
#  2729 2822 1607 3050 1363  412 2134  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 530  499 3027  110  496 1239 2012 1829 3337 1430 2857 2038 2218 2586
#  1607  738  596 3050  412  340 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1580 1183  231 3302 2618  497 1578 3096 2117 2525 2076 2038 3316  258
#  3287 1482 2171 1331 1539 3003 3298  412 1787  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2507 1814 2326 1460 3005 2229 2857  652 3295 2932  498 2623 1607 3315
#  3015 3003 3298 3050  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2516 1293  530 1036 3031  554  477  368 3319 2136 2586 3315 2872 2472
#  3050  340 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 741  446 2681 3328  121 1993  328 2836 3023 3268 2656 2084  477 2038
#  3319 2553  782 3287 1607 2737 2157 3296 3003  412  340  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1291 1079 1607 2737 2472 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1423 1910 2525 1770 1014 2708 2171 2157 3003 3007  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 511 1417 2410 1007 2013 2485 3194 1800 3104 3190 1061 2822 2872 3007
#   340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3386 2155 2623 1607 2737  873 3003]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2592 1295 1829 2076 1796 1695 1607 2737 3153 2330 3003 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1257 2084 3319 2013 2085 3355 3137  401 1607 2737 3003 2472  273 3050
#  2188 1787 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  14  227  647 2509 2314  999 1245 1555 2229  214  258  259  873 3003
#  3050 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1033 2695 2683 2458 1005  366  438 3147 2647 1963 1331  637 2872  596
#  3007  340 3379 3002 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2890 2758 1872 1421 2472 1102 1787  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3116  875   74 3264 1339 2256 2586 1331 3315  412 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2994 3357 2629 3147 1963 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2175  581  317 2786  562 2775 1295 1292 1796 1556 3240 3011 1607 2737
#  2157 3003  596 1787 3379  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1199 2775 2778 2107 3002 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 930 2229 2136 2472 1787 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3351 3054  797 2443  763 2143  296 2229 3147 2171  873  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 965  154 3102  969 2769 1601 1245 2231  324 2788 2084  258   31 2822
#  1607 2737  412]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2415 1094 1077  532  887  814 1832 3027 1408 1553  632  657 2656 1796
#  3240  536  337 1276 2184  340 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2828  332 1007 3147 1607  340 1794  147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2614 1636 1676 1258 1325 1020 2623  637  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3062 2832 2229 1831 2708 2330  596 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3103  361 2885  729 2143 2038 2725  536 3312 2171 2157 3003 2134 2657
#  3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1639  600 2182 3414 1295  998  366 2136 1607 2737 3003 2021  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2738  952 2955 2091 2053  328 1295 2229   31 3003 1360  596 3050 2021
#   412 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2518 1385 1556 2054  873]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3018  506  859 2618 2831 3023 2525  117 3240 3287  259 3202 3296 3275
#  1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3031 3319 1337 1607  596 1794 3123]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 171  786 1343  697 3393  442 3319 2013 2472  340 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2925 1426 1330 3168 1460 1254 2730 3003  340 2134 2657 3123 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1671  639  447  822 3080 2229    8 2822 1607 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  67 1904 1520 2143 1751 2425 2229 1556 2553 3287 1607 2157 3003 2134
#   147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3354   85  422 2040 3291 1425 1747  478 2339   25 2216 2936 2553  384
#  3287 2171 1607 3202 2157 3296 3003  412  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1777  223 2390 1245 1345  574 1020 2656 1796 2857 1556 3104 3355  259
#  2171 2751 3003 2134 1320 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1256 1752 2600 1558  834 2577 1041 3373 2114 2027 1829 3337 2544 2038
#  2218 1482  401 1607 3003 3050  340 3379 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2946 3117 1270 3319  337 2586 1607 2737  637 2157 3003 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1166  600 1805 3034 1105 2018  386 2737 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3211 3093   38  634 3361  783 2028 2496  927 2617 2229 1332  291 3147
#  1607 3153  637  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1913 2917  815 1822  697 2229  782 3355 2623 2157 3002 1794 2134 2657
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  96  236 2372 1566   29  554 2229 3147  395 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2472 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3301 1816  324 1517 2623 2021  412 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1301  632 2788 2084 1861 2198 1337  760 1607  637 2472 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1761 3286  549 1517 1607 2737 3003 2472]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2963 2614 3043 3117 2076 1337 2623 1607 1331 2737 3003 2021 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1660  478 2152 2052 2902 2229 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1516 1560  715 3027 2027 1269 1829  133  477 1796 3240 2157  449 2107
#  1276  412 3379 3002 1320  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2003 2468 1301  438  291 1312  536 1607 3003 3007  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1394 2229 1337 1607 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1588 1309 2827 3059 2902 1796 1556 3240  760 3003 3050  340 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 673 1556  733  536 2623 1607 2737]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2010 1556  259 2157  449 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1905 2327 2455 1218 1338 2525 1770 3393 2218 2211 2198 1607 3050 2188
#  1787 3007]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2797  435  479  448  868  103 1910 2216 2052   21  108 2229 2038 2218
#  1831 3147 1549   23 2343 2171 1607 2157 3296  412  340  395  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2575 1362 1490  729 2229 1607 2097 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1097 3286 3023 2902 2018  477 1240 3057 2157 3050 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2472 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1673  256  863 2229 2586 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 383 3395 1513 2587 3018 2175  657  504 1656 3287 3280 3003 3002  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3049  606 3117 2229  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1527  966 1480  427  825 2285 1574 1721 3322 1263 1558  497 1885  336
#   477 1656 2623  637 2157 2107 3050  340 3002 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3248 3260 1417  574 2194 3355 2157  873]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2515 1947 1324 2229  289 1533 3312 2623 3202 3153 1360  273 3007  340
#  2134 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3131 3345 2705 2708]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2703 1311 2290 3080  600 1361 1805  671 2553 2822 1607 2157 3003  412]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1594  563 2902 2229 2188 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1074  654 1818 2642 3384  700 2902  881 2158 1607 2737 2157 3003 1794
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2096 1737 2670 3080 1056 3100  292 2571 1337  401 1607 2157]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1925 1735 3042 1541 2091 3358 1295 2746  987 2171  596 2021 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1555 1607 2737  596 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3326  659 1487 2496 1339 3117  258 1607 2737 3003  340 1794 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1090 2152 2229 3319 1607 2737 3003  596 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3098 1650  522  323 1178 2408 1209  401 2751 2097  596 1787  340 3002
#  1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3084 1767 1165 3319  596 2021 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3406  915  184 3120 1295 3412  702  368 1555 3319 1963 2737  449 2472
#   273 3050 1787 3007  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 568  422   65 2565 2299 1566  964 2705  384 1607 2157  873 2793  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1450 3065 2672  480 2696 1294 2439  632  554 3319 1061  313 2171 2157
#  2107 3003 2472 1787 2173  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1655  927  697 2656 2755  652 3295  536 3355 2623 1607  340 3002 2134
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2673 1994 1294 3027 1096 3337 2038 3240 2778 2586 1607 2157 3296 2766
#  3003  596 1787 1645 3002 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3353 3117  873  766 3007 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 607 2197  927 2823 3147 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1893 1017 3359 1752  562 1790 1306 2229 2705 1549  873  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 904 2656 1612 1517 2816 3319 3147 2136 3194 1209 3011 1607 3296 2472
#  2021  412  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2731  443  827 2474 3043 1492 1417 2746  749 2788 2084 2076 2816  738
#  3003 2097 2188  340  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 737  622  511 1092 2211 2157  766 3003 2021 1645]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 960 1450 1417 2900 1556 1061 3003 3050 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2639 3314 3161 1527  383 2496 2827 2277 2108 2120 2862 1656 3287 2586
#  1607  738 3003 2173 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2318  441 1993 2198 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 195  174 1221  190  165 1751 2746  749  117 2076 3240 1209 2158 2171
#  2021  340 1794 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1408 3034 2076 2737 3003 2134 3123]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2658  297 2853 1961  292  697  504 1324  205 3202  637 3296 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 976 2462  876 1752 3220 1819 2615 1846  324 1556 1607 2157  449  412
#  2188 1787 3007  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2935 1419   76   20 2658 2114  134  974  377  632  697 2936 1007 2553
#  1240 1607 2737 3003 1645  340  395 2134  147 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2646 1084 3278 2430 1667 1720   64  176 3335 3043  322 1607 1331  412]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1050  745 2557 2676 1927 2675 2656  549 2583 3355 2157 2472 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3234  129  639  124  554  259 2623 2472 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2541 2695 1566  574  286 3355 2171 2157  873 3003 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2161 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1644  980 2033 1676   65 2565 1096 1751 2163 1176  133 2229 2367 2136
#  2729  384 2623 1607 2737 2157  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2162  732 1271 2907 2773 1345 2229 3137 1645 3002 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 773 3234  645  554 2054 1312 2623 1607 2737  596 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 971  846 1417 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3149 3299 2824 2999 2054 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2245 1696 1251  878  428 1686 1845 2279  933  692 3158 3072  126 2398
#   845 1983  430  951 1672 1093  345  693 1138  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3014 2823  536 1337 1607 3296 1462 3123]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  58 2125  611 2782 1242 1537 1020 1796  637  340 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3401  590 1270 2229 3147 1645]
# Zipped series: Series([], dtype: object)
# ...
#   412 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2032 1255 1330 3117  549 3319 2729 1337 1607 2157 3003 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3309  353 2300 2466  646 3232 1523 2633 1747 3286 1354 2216  407 2076
#  1533 3194 3312 2171 1607 3296 1360  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2139  399  358 1573  815 1301  109 1910 1125 2746 2656  337  259 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2736  270 1417 2737  449 3003 2472]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1387 2502 1220 2818 1662  598 2277 2108 2120 2018 2857 3194  337 2751
#  3007  340 3002 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1293 3373  901 1805 1444 2224 3316 2737 3003  273  412 2188  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1468  123 2426 2025 2066 1397  376  958 1520 2038 3067 1076 3287 2343
#    13 2171  401 1607 3296 1360 2097  412  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3227  595 2891 2222  369 1008 3240 3355 1607 3003 1360 3298 1102  412
#  3007 1794 2134 3123  147 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3089 3068 1556 2054 2586 3003  596 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2808 1204  136 3096 1241 1993 1232  357 3097 2623  873 3001 1787  340
#  3002  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1846  554 2705 3355 3287 2551 2586 1607 2737  738  596  340 1794 2134
#  1320  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1697  556  786 3185 1846 1444  292  697 2788 2084  357 1555 3240 3355
#  3287 1482 1607 2472 2021 1787  340  395 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 695 1394 1304  441   25 2229 1800 2198 1337   13 2171 1607 2184 2188
#   340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  63 1367 2355  761  639 3150 1566 2143  457  970 2054 2583 2171 1607
#  2134 1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2830 1271 3261 1475 3023 2076 1007 2013 1607 2737 3003 2472  273 2188
#  3007  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1653 1607 2737  596 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 786  697 2525 3005 1489 2038 3011  259 2157 3296 3002 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1957 2229 2472 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2033 2040  478 1417 2097  412 2188 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2396 1627   28 2167 1230 2847 1947 3328 2114 1556 2038  258 1061 3097
#    13 3153 2157 3298 3050  340 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2946 1020 2656 1555 1796 2737  637 3003  395 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2796 2557 1279 1607 2737 2872 3003 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2797 2922 2902 1607 2737 3003 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2253 2468 2229 1556 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2237 2749 1495 2892 2680 2027  996  632  442  652 1607 2737 2157  449
#  3003  273  412 1787 3007  340  147 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1451 1184 1361 3360 1092 2136 1337 3355 1607 2157  596  412 2188 1320
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 921 2146 2591   37  308 3080 2238 1607 3153]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2474 2081   29 2100 2823 2229   13 2751 2188 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 956  746  975 2572 2229 2583 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1133 2902 1796 2857 2737 1360 1794 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 459 1779 1704 3319 1533 3355 3287 3097 2586 1607 2737  873 3003 1360
#  3050 1794 3123  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1607 2737 3003 2188 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1266  651 2071 2112 2225  117  911 2425  368 2229 1014 1800  881 2553
#  1607 1276 3050 3007  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1176 1306  911 1270 2737 3003  596  273 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3288 3174 2052  670 3246 2229 3097 2171  596 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1307 3117 1607]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2777 2861 2939  920 2180 1991 3248 1806 1354 2862 2038 1533 1076  401
#  2737 3296 3003 1360 3050  412  340  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2063 1747 2155  970 2229 1695 3319 1549  258 3219 1607 1963 2737 3003
#   596  340 3002 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1055  927 3256 1517 3319 3240 1808 1607 2737 3003]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2152 2076 2229 2623 1607 2737 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3320  283  133  549 2900 2705 3393 3194 1800 2553  760 1607 2872 2107
#   873 1360  596 1787 1794  147 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2431 1615 1300 1999 2124 2775  743 1517  108 2229 3319 3240   31 1337
#  2623 1607 2737 2157  873 2472 3050 1794 1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1271 2727 2737 3003  273 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3403  196  639 2229 2623  596 2021 2188 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  82 2434 2220 1736  317 2026 2054 2800  384 2171 2157 3003 1360 3050]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2986 1570  133 3153 2107 3296 1360 3002]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1960  796 1767 1254 1556 2218 1331 2157 3007 2134 1320]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3171 1300 3064 2902  117 2623 1963 1331 3153  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3035 2461 3175 3213 1295 3003 1787  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1422 2763  645 2299 3117 2706 2076 2421 3067  384 2623 2737 3003 1360
#   596  273 2021  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 946  343  933  332 2866  729 2236 2425 1796  205 1800 3003  596  412
#  1794 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1727  120 1947 3302 2836 1607 2737 2872 2157 3003 2097  596 1102 2188
#  1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2603 1547 2446 1556  384 3355  337  259 1331  738 2472 2188  340 1794
#  2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2300 1930 2968 2310  497  973  857 2038 3355 1482  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1643 1655 2345 1295 2158 2171 2157  596  412 1787 3007  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2804 1333 3026 1527  999 1566 1829 2229 1556 2038 1831 1549  401 2586
#   596  412 3002  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1732 1074 3360  574 2525 2656 3240 2583 3011  259 3296  873 3003  340
#   395 1794 1744 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 586 2231 2836 2225 3319 1607 3050 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 270 2084 1007 2013 2085 2737 3298 3050 1102 2188  340 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1264 2891 3099 3192 1008 2403 2705 2932 2751 2472 1787 3007  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2033 3319 2198 2472  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1883 1769 2291 2033 3361 3192 3150 1444 3240 3355 1240 2472  596 2021
#  1787  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 838  342 1836 2902 2229 1607 2737 3003 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 189  163 3302 1557 3319 1607 2737 2134 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2328 2103 2743 3406 1777 2002 3412  117 1270 3147 3355 3097 2171]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1055  324 1517 2218 3240 2013 2698 2754 2553 3190 1928 2586 2751 2157
#   412 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2822 2472 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2825 2456  527 1427 1222 1008 1292   78 1556 3319 2136  258  401 1963
#  1331 2472 1787 1645 3007  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1344 2294 3175 1857   58 3302 1962 3360   78 2229 2136   31 1482 1607
#  3050  395 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2122 3266 2855 2971   96 1047  478  108 2038 2218 2054 3147  784 2586
#  1607 1331 2737 3003 1360 2021  412 2188 1794 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2007 2404 1648 1298  567   12 2570 2627 1688  733 3319  596 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2722 3153 2157 2657 3123]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1991 3371  632 1796 1061 1607 3003  596 1787 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3248 2925 1365 2157]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1544 3182  607 1929  927 2824  259 2623 1607 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3310 3245 3105 1846 2216 2225 2084 1695 2085 3355  259 1607  873 3003
#  1320 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1470 3274 1049 2358 1834 2074 1517 2076  442 3240 3194 2171 2586 1607
#  2737 3003  596 3050 1787  340 3123  147 3275 1664]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1356 3324 2229  596 2188 1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2076 1270 1607 2737 3003  596 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1528 2082 1733 2935 2955 1361 2911 3031 2277 2108 2120 2656 2367  699
#  1607  738 2157  873  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1304 3221 2773 2746 3147  498  596 2021 2188 1787 1794  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1617 1270 2229  691 2623 2472 1102 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2266  830  982  805 1340 3031 1846 3117 2706 1829 2816 1796 3319 1240
#   873 2097  412 2173  340 1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2157  449 2188 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2182  875 1927 2827 3059 1092 3319 2211 3147 2583 2708 3355 2171 2157
#  2472  340 1794 2657]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1662 3043 2114 1492 2773 2867 2277 2108 2120 2700 2367 3319 2157 1360
#   596 3050  412 1787]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [  11 1909 2666 1103  771    7 1745 3361 1765 1056 2408  101 3319 3147
#     0 2623   23 2343 1607 2737 1360  412 1787 2173  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1249  230 1939 2229 1556 2471 1607 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [3128 1066 3248  296  793 3003 1360  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 959 3239 3140 2076 1796 2857 1209 1240 2737 2472 2134]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2919 2148  317 1210 2231 2100 1295 1896  682 2038 1209 3312 2737 3296
#  3015 3003 1360  596 1787  147 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2542 1735 1301 3059 2656  911 2788 2084  438 2171  401  596 3001 1787
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1272 2148  117 1270 3003]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 780 1224 3136 1216 3264  848 2114 2053 2525 1770 2038 3316 2177 1607
#  2737 2157 3003 2097 3050 1787  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1346  895 2438 2733 1994  639  749 1796 2857 2700 1607 2157  596 2021
#  1787  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2972 1975  104 2719 1281   25 3117 3052 2224 2038 3240 3147 2136  760
#  1076   13 2171 2586 2157 2107 3296 2097  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2931  319 1330 1578 1851 1566 2216 1254 1770  554 2038 2729  258  313
#  3312 1076 3287 2586 2157 3296 3003 3050  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2061 2225 2229 3147 2136 2754]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1305 1434 1229 2259  794 1557 1417  292 2705  442 2218 3147 2698 3194
#  1656 2737  637 2157  273 2188 3007 2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2705 2822 2188]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2440 1450  786  659 1487 2496 1295 2171 3296 3003  340 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2273 3223 1340  596 1794]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 939  182  431  145 3258 1230 1609 1419 2775 1910 2038 2218 2211 2343
#  2171 3202 2157 3296 3050  412  340  395  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 257 2306 2732 1752 2685 1607 2872 3003  596 1787  340]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1241 2833  296 1556  733 3319 2754  337 1607 1963 1331 3001 2173  340
#  1320  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 795 3238  343 2642 2056  292 2084 1517 1796 2698 1607 2737 2872  412
#  2134  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1220 3112  370 2091  901 2789 1695  442 2737 2021 1645  340 3002 2134
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2140 2745  958 1991 2474 2152 1361 3282 2421 2822 1607  637  766 1539
#  3003 2188 1645 2134 2657  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [2103 2836 1987 1607  873 1744]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1688  213  875 3328 1578 1805 3360 2425 2229 3147  637   92  340 1319
#   147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [ 192  968 3178   11 3249  101 1086 2163 2656   21 1954  108 2553   31
#    13 1607 1360 1363  340 2134 3275]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1073  891 1935 2257 1119 1242 1746 3286 2068 2999 1954  108 2038 1533
#   258 1656 1076 3315 3296 1462 1360 3050  340  147]
# Zipped series: Series([], dtype: object)
# Indices in the sparse matrix: [1711 3021 1140  760 2157 3003]
# Zipped series: Series([], dtype: object)

# %% [markdown]
# Modeling the UFO dataset, part 1

# %%
X = ufo_dropped.drop(['type', 'country_enc'], axis=1)
y = ufo_dropped['country_enc']

# %%
print(X.columns)
# Out:
# Index(['changing', 'chevron', 'cigar', 'circle', 'cone', 'cross', 'cylinder',
#        'diamond', 'disk', 'egg', 'fireball', 'flash', 'formation', 'light',
#        'other', 'oval', 'rectangle', 'sphere', 'teardrop', 'triangle',
#        'unknown', 'month', 'year'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()

# Split the X and y sets using train_test_split, setting stratify=y
train_X, test_X, train_y, test_y = train_test_split(X, y, stratify=y)

# Fit knn to the training sets
knn.fit(train_X, train_y)

# Print the score of knn on the test sets
print(knn.score(test_X, test_y))
# Out:
# 0.8736616702355461

# %% [markdown]
# Modeling the UFO dataset, part 2
#
# Finally, let's build a model using the text vector we created, desc_tfidf, using the filtered_words list to create a filtered text vector. Let's see if we can predict the type of the sighting based on the text. We'll use a Naive Bayes model for this.

# %%
y = ufo_dropped['type']

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# Assuming desc_tfidf and y are properly defined

nb = GaussianNB()

# Use the list of filtered words we created to filter the text vector
filtered_text = desc_tfidf[:, list(filtered_words)]

# Print information for debugging
print("Shape of desc_tfidf:", desc_tfidf.shape)
print("Shape of filtered_text:", filtered_text.shape)
print("Filtered words:", filtered_words)

# Split the X and y sets using train_test_split, setting stratify=y
train_X, test_X, train_y, test_y = train_test_split(filtered_text.toarray(), y, stratify=y)

# Fit nb to the training sets
nb.fit(train_X, train_y)

# Print the score of nb on the test sets
print(nb.score(test_X, test_y))
# Out:
# Shape of desc_tfidf: (1866, 3422)
# Shape of filtered_text: (1866, 0)
# Filtered words: set()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[176], line 20
#      17 train_X, test_X, train_y, test_y = train_test_split(filtered_text.toarray(), y, stratify=y)
#      19 # Fit nb to the training sets
# ---> 20 nb.fit(train_X, train_y)
#      22 # Print the score of nb on the test sets
#      23 print(nb.score(test_X, test_y))
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1351, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1344     estimator._validate_params()
#    1346 with config_context(
#    1347     skip_parameter_validation=(
#    1348         prefer_skip_nested_validation or global_skip_validation
#    1349     )
#    1350 ):
# -> 1351     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/naive_bayes.py:263, in GaussianNB.fit(self, X, y, sample_weight)
#     240 """Fit Gaussian Naive Bayes according to X, y.
#     241
#     242 Parameters
#    (...)
#     260     Returns the instance itself.
#     261 """
#     262 y = self._validate_data(y=y)
# --> 263 return self._partial_fit(
#     264     X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     265 )
#
# File ~/.local/lib/python3.10/site-packages/sklearn/naive_bayes.py:423, in GaussianNB._partial_fit(self, X, y, classes, _refit, sample_weight)
#     420     self.classes_ = None
#     422 first_call = _check_partial_fit_first_call(self, classes)
# --> 423 X, y = self._validate_data(X, y, reset=first_call)
#     424 if sample_weight is not None:
#     425     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1192, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1187         estimator_name = _check_estimator_name(estimator)
#    1188     raise ValueError(
#    1189         f"{estimator_name} requires y to be passed, but the target y is None"
#    1190     )
# -> 1192 X = check_array(
#    1193     X,
#    1194     accept_sparse=accept_sparse,
#    1195     accept_large_sparse=accept_large_sparse,
#    1196     dtype=dtype,
#    1197     order=order,
#    1198     copy=copy,
#    1199     force_all_finite=force_all_finite,
#    1200     ensure_2d=ensure_2d,
#    1201     allow_nd=allow_nd,
#    1202     ensure_min_samples=ensure_min_samples,
#    1203     ensure_min_features=ensure_min_features,
#    1204     estimator=estimator,
#    1205     input_name="X",
#    1206 )
#    1208 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1210 check_consistent_length(X, y)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/utils/validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033     n_features = array.shape[1]
#    1034     if n_features < ensure_min_features:
# -> 1035         raise ValueError(
#    1036             "Found array with %d feature(s) (shape=%s) while"
#    1037             " a minimum of %d is required%s."
#    1038             % (n_features, array.shape, ensure_min_features, context)
#    1039         )
#    1041 return array
#
# ValueError: Found array with 0 feature(s) (shape=(1399, 0)) while a minimum of 1 is required by GaussianNB.
